# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install einops
# !pip install jiwer
# Out:
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Installing collected packages: einops
# Successfully installed einops-0.4.1
# Collecting jiwer
#   Downloading jiwer-2.3.0-py3-none-any.whl (15 kB)
# Collecting python-Levenshtein==0.12.2
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 6.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein==0.12.2->jiwer) (57.4.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149870 sha256=c1321d2120599f14b6097c71b741ca5a366afa6425006f36800a0ce7916caf21
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein, jiwer
# Successfully installed jiwer-2.3.0 python-Levenshtein-0.12.2

# %%
cd /content/drive/MyDrive/AIC-Lab/Vietnamese_handwriting/OCR_release11_03
# Out:
# /content/drive/MyDrive/AIC-Lab/Vietnamese_handwriting/OCR_release11_03

# %%
# !python test.py
# Out:
# ấp Liêm Thuận, Xã Phước Thuận, Huyện Tuy Phước, Bình Định

# %% [markdown]
# #debug

# %%
import matplotlib.pyplot as plt
from PIL import Image
import yaml
from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg

with open("inference.yaml", 'r') as stream:
    config = yaml.safe_load(stream)

detector = Predictor(config)
img = 'sample/test84.png'
img = Image.open(img)
plt.imshow(img)
s = detector.predict(img)
print(s)
# Out:
# ấp Liêm Thuận, Xã Phước Thuận, Huyện Tuy Phước, Bình Định
